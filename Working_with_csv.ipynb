# %% [markdown]
# <a href="https://colab.research.google.com/github/RitukumariBE/ML-Notebook/blob/main/Working_with_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/campusx-official/100-days-of-machine-learning.git
# Out:
# Cloning into '100-days-of-machine-learning'...
# remote: Enumerating objects: 591, done.
# remote: Counting objects: 100% (216/216), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 591 (delta 182), reused 173 (delta 173), pack-reused 375 (from 2)
# Receiving objects: 100% (591/591), 16.81 MiB | 16.99 MiB/s, done.
# Resolving deltas: 100% (229/229), done.

# %%
# %cd 100-days-of-machine-learning
# Out:
# /content/100-days-of-machine-learning/100-days-of-machine-learning

# %%
# !ls
# Out:
#  adaboost_demo.ipynb				   day40-iterative-imputer
# 'day15 - working with csv files'		   day42-outlier-removal-using-zscore
# 'day16 - working-with-json-and-sql'		   day43-outlier-removal-using-iqr-method
#  day17-api-to-dataframe				   day44-outlier-detection-using-percentiles
#  day18-pandas-dataframe-using-web-scraping	   day45-feature-construction-and-feature-splitting
#  day19-understanding-your-data-descriptive-stats   day47-pca
#  day20-univariate-analysis			   day48-simple-linear-regression
#  day21-bivariate-analysis			   day49-regression-metrics
#  day22-pandas-profiling				   day50-multiple-linear-regression
#  day24-standardization				   day51-gradient-descent
#  day25-normalization				   day52-types-of-gradient-descent
#  day26-ordinal-encoding				   day53-polynomial-regression
#  day27-one-hot-encoding				   day55-regularized-linear-models
#  day28-column-transformer			   day56-lasso-regression
#  day29-sklearn-pipelines			   day57-elasticnet-regression
# ...

# %% [markdown]
# 1. Importing pandas

# %%
import pandas as pd

# %% [markdown]
# ## 2.OPening a local csv file

# %%
df= pd.read_csv('/content/100-days-of-machine-learning/day15 - working with csv files/aug_train.csv')
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# ## 3.Opening a csv file from an url

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers ={"User-Agent":"Mozilla/5.0(Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url,headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# ## 4. Sep parameter

# %%
import pandas as pd
pd.read_csv('/content/100-days-of-machine-learning/day15 - working with csv files/movie_titles_metadata.tsv', sep='\t')
# Out:
#        m0  10 things i hate about you  1999  6.90     62847  \
# 0      m1  1492: conquest of paradise  1992   6.2   10421.0
# 1      m2                  15 minutes  2001   6.1   25854.0
# 2      m3       2001: a space odyssey  1968   8.4  163227.0
# 3      m4                     48 hrs.  1982   6.9   22289.0
# 4      m5           the fifth element  1997   7.5  133756.0
# ..    ...                         ...   ...   ...       ...
# 611  m612                    watchmen  2009   7.8  135229.0
# 612  m613                         xxx  2002   5.6   53505.0
# 613  m614                       x-men  2000   7.4  122149.0
# 614  m615          young frankenstein  1974   8.0   57618.0
# 615  m616                   zulu dawn  1979   6.4    1911.0
#
#                                   ['comedy' 'romance']
# 0          ['adventure' 'biography' 'drama' 'history']
# 1                ['action' 'crime' 'drama' 'thriller']
# 2                     ['adventure' 'mystery' 'sci-fi']
# ...

# %%
pd.read_csv('/content/100-days-of-machine-learning/day15 - working with csv files/movie_titles_metadata.tsv',sep='\t',names=['sno','name','release year','rating','votes','genres'])
# Out:
#       sno                        name release year  rating     votes  \
# 0      m0  10 things i hate about you         1999     6.9   62847.0
# 1      m1  1492: conquest of paradise         1992     6.2   10421.0
# 2      m2                  15 minutes         2001     6.1   25854.0
# 3      m3       2001: a space odyssey         1968     8.4  163227.0
# 4      m4                     48 hrs.         1982     6.9   22289.0
# ..    ...                         ...          ...     ...       ...
# 612  m612                    watchmen         2009     7.8  135229.0
# 613  m613                         xxx         2002     5.6   53505.0
# 614  m614                       x-men         2000     7.4  122149.0
# 615  m615          young frankenstein         1974     8.0   57618.0
# 616  m616                   zulu dawn         1979     6.4    1911.0
#
#                                                 genres
# 0                                 ['comedy' 'romance']
# ...

# %% [markdown]
# ## 5.Index_col Parameter

# %%
df= pd.read_csv('/content/100-days-of-machine-learning/day15 - working with csv files/aug_train.csv')

# %%
pd.read_csv('')
